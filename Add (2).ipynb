# %%
record = { 10001 : { "prod_name"  : "School Bag"     , "price" : 2000 , "quantity" : 50 , "Brand" : "Skybags"          , "Mfg_date" : "29/8/2020" }, 
           10002 : { "prod_name"  : "Track Bag"      , "price" : 500  , "quantity" : 60 , "Brand" : "Puma"             , "Mfg_date" : "9/5/2021" },
           10003 : { "prod_name"  : "Gym Bag"        , "price" : 300  , "quantity" : 40 , "Brand" : "American Tourist" , "Mfg_date" : "2/2/2021" },  
           10004 : { "prod_name"  : "Travel Bag"     , "price" : 900   , "quantity" : 100  , "Brand" : "Adidas"        , "Mfg_date" : "19/4/2020" },
           10005 : { "prod_name"  : "Hand Bag"       , "price" : 400  , "quantity" :   200, "Brand" : "Adidas"        , "Mfg_date" : "1/7/2020" },
           10006 : { "prod_name"  : "Laptop Bag"     , "price" : 800   , "quantity" : 100  , "Brand" : "Apple"        , "Mfg_date" : "20/3/2020" },
           10007 : { "prod_name"  : "Sports Bag"     , "price" : 200   , "quantity" :  250 , "Brand" : "Puma"        , "Mfg_date" : "19/7/2021" },
           10008 : { "prod_name"  : " Ball pen"      , "price" : 50   , "quantity" : 200  , "Brand" : "Soccer"        , "Mfg_date" : "27/9/2020" },
           10009 : { "prod_name"  : "Pencil"         , "price" : 25   , "quantity" : 200  , "Brand" : "Adidas"        , "Mfg_date" : "19/4/2020" },
           10010 : { "prod_name"  : "Lead pencil"    , "price" : 40   , "quantity" : 100  , "Brand" : "Camel"        , "Mfg_date" : "11/3/2021" },
           10011 : { "prod_name"  : "Rular"          , "price" : 10  , "quantity" : 80  , "Brand" : "Camlin"        , "Mfg_date" : "29/8/2021" },
           10012 : { "prod_name"  : "Scissors"       , "price" : 80   , "quantity" : 50  , "Brand" : "Classmate"        , "Mfg_date" : "9/2/2021" },
           10013 : { "prod_name"  : "Tape measure"   , "price" : 100   , "quantity" : 20  , "Brand" : "Cello"        , "Mfg_date" : "30/5/2021" },
           10014 : { "prod_name"  : "Campass box"    , "price" : 200   , "quantity" : 30  , "Brand" : "Classmate"        , "Mfg_date" : "29/6/2021" },
           10015 : { "prod_name"  : "Water bottle"   , "price" : 150   , "quantity" : 40  , "Brand" : "Milton"        , "Mfg_date" : "17/11/2020" },
           10016 : { "prod_name"  : "Tiffin box"     , "price" : 200   , "quantity" : 50  , "Brand" : "Milton"        , "Mfg_date" : "14/6/2020" },
           10017 : { "prod_name"  : "Drawing book"   , "price" : 90   , "quantity" : 30  , "Brand" : "Funa"        , "Mfg_date" : "19/8/2021" },
           10018 : { "prod_name"  : "Milk chocalate" , "price" : 150   , "quantity" : 50  , "Brand" : "Dairy milk"        , "Mfg_date" : "20/6/2021" },
           10019 : { "prod_name"  : "Scolar Book"    , "price" : 60   , "quantity" : 200  , "Brand" : "Jupiter"        , "Mfg_date" : "4/8/2021" },
           10020 : { "prod_name"  : "Brush"          , "price" : 30   , "quantity" : 50  , "Brand" : "camlin"        , "Mfg_date" : "29/4/2021" },
           10021 : { "prod_name"  : "Sketch pen"     , "price" : 20   , "quantity" : 40  , "Brand" : "Cello"        , "Mfg_date" : "11/6/2021" },
           10022 : { "prod_name"  : "OilPaint colors", "price" : 200   , "quantity" : 60  , "Brand" : "Funa"        , "Mfg_date" : "21/5/2021" },
           10023 : { "prod_name"  : "Color Pencil"   , "price" : 20   , "quantity" : 40  , "Brand" : "Classmate"        , "Mfg_date" : "8/5/2021" },
           10024 : { "prod_name"  : "Story book"     , "price" : 100   , "quantity" : 10  , "Brand" : "Oxford"        , "Mfg_date" : "15/7/2021" },
           10025 : { "prod_name"  : "Black Board"    , "price" : 300   , "quantity" : 30  , "Brand" : "Camlin"        , "Mfg_date" : "23/4/2021" },
           10026 : { "prod_name"  : "Slate"          , "price" : 100   , "quantity" : 36  , "Brand" : "Usha"        , "Mfg_date" : "19/4/2020" },
           10027 : { "prod_name"  : "White Board"    , "price" : 300   , "quantity" : 10  , "Brand" : "Classmate"        , "Mfg_date" : "1/9/2020" },
           10028 : { "prod_name"  : "Marker"         , "price" : 50   , "quantity" : 75  , "Brand" : "Montex"        , "Mfg_date" : "17/10/2020" },
           10029 : { "prod_name"  : "Ink Bottle"   , "price" : 40   , "quantity" : 36  , "Brand" : "Cello"        , "Mfg_date" : "20/11/2020" },
           10030 : { "prod_name"  : "Umbrella"   , "price" : 350  , "quantity" : 44  , "Brand" : "Adidas"        , "Mfg_date" : "25/3/2021" }
         
         
         
           
         }

# %%
record
# Out:
# {10001: {'prod_name': 'School Bag',
#   'price': 2000,
#   'quantity': 50,
#   'Brand': 'Skybags',
#   'Mfg_date': '29/8/2020'},
#  10002: {'prod_name': 'Track Bag',
#   'price': 500,
#   'quantity': 60,
#   'Brand': 'Puma',
#   'Mfg_date': '9/5/2021'},
#  10003: {'prod_name': 'Gym Bag',
#   'price': 300,
#   'quantity': 40,
#   'Brand': 'American Tourist',
#   'Mfg_date': '2/2/2021'},
#  10004: {'prod_name': 'Travel Bag',
#   'price': 900,
#   'quantity': 100,
#   'Brand': 'Adidas',
#   'Mfg_date': '19/4/2020'},
#  10005: {'prod_name': 'Hand Bag',
#   'price': 400,
#   'quantity': 200,
#   'Brand': 'Adidas',
#   'Mfg_date': '1/7/2020'},
#  10006: {'prod_name': 'Laptop Bag',
#   'price': 800,
#   'quantity': 100,
#   'Brand': 'Apple',
#   'Mfg_date': '20/3/2020'},
#  10007: {'prod_name': 'Sports Bag',
#   'price': 200,
#   'quantity': 250,
#   'Brand': 'Puma',
#   'Mfg_date': '19/7/2021'},
#  10008: {'prod_name': ' Ball pen',
#   'price': 50,
#   'quantity': 200,
# ...

# %%
import json

# %%
js = json.dumps(record)

# %%
js
# Out:
# '{"10001": {"prod_name": "School Bag", "price": 2000, "quantity": 50, "Brand": "Skybags", "Mfg_date": "29/8/2020"}, "10002": {"prod_name": "Track Bag", "price": 500, "quantity": 60, "Brand": "Puma", "Mfg_date": "9/5/2021"}, "10003": {"prod_name": "Gym Bag", "price": 300, "quantity": 40, "Brand": "American Tourist", "Mfg_date": "2/2/2021"}, "10004": {"prod_name": "Travel Bag", "price": 900, "quantity": 100, "Brand": "Adidas", "Mfg_date": "19/4/2020"}, "10005": {"prod_name": "Hand Bag", "price": 400, "quantity": 200, "Brand": "Adidas", "Mfg_date": "1/7/2020"}, "10006": {"prod_name": "Laptop Bag", "price": 800, "quantity": 100, "Brand": "Apple", "Mfg_date": "20/3/2020"}, "10007": {"prod_name": "Sports Bag", "price": 200, "quantity": 250, "Brand": "Puma", "Mfg_date": "19/7/2021"}, "10008": {"prod_name": " Ball pen", "price": 50, "quantity": 200, "Brand": "Soccer", "Mfg_date": "27/9/2020"}, "10009": {"prod_name": "Pencil", "price": 25, "quantity": 200, "Brand": "Adidas", "Mfg_date": "19/4
# ...

# %%
record
# Out:
# {10001: {'prod_name': 'School Bag',
#   'price': 2000,
#   'quantity': 50,
#   'Brand': 'Skybags',
#   'Mfg_date': '29/8/2020'},
#  10002: {'prod_name': 'Track Bag',
#   'price': 500,
#   'quantity': 60,
#   'Brand': 'Puma',
#   'Mfg_date': '9/5/2021'},
#  10003: {'prod_name': 'Gym Bag',
#   'price': 300,
#   'quantity': 40,
#   'Brand': 'American Tourist',
#   'Mfg_date': '2/2/2021'},
#  10004: {'prod_name': 'Travel Bag',
#   'price': 900,
#   'quantity': 100,
#   'Brand': 'Adidas',
#   'Mfg_date': '19/4/2020'},
#  10005: {'prod_name': 'Hand Bag',
#   'price': 400,
#   'quantity': 200,
#   'Brand': 'Adidas',
#   'Mfg_date': '1/7/2020'},
#  10006: {'prod_name': 'Laptop Bag',
#   'price': 800,
#   'quantity': 100,
#   'Brand': 'Apple',
#   'Mfg_date': '20/3/2020'},
#  10007: {'prod_name': 'Sports Bag',
#   'price': 200,
#   'quantity': 250,
#   'Brand': 'Puma',
#   'Mfg_date': '19/7/2021'},
#  10008: {'prod_name': ' Ball pen',
#   'price': 50,
#   'quantity': 200,
# ...

# %%
type(js)
# Out:
# str

# %%
fd = open ("record.json", 'w')
fd.write(js)
fd.close()

# %% [markdown]
# ## read data from json

# %%
fd = open("record.json",'r')
r = fd.read()
fd.close()

record = json.loads(r)

# %%
record
# Out:
# {'10001': {'prod_name': 'School Bag',
#   'price': 2000,
#   'quantity': 50,
#   'Brand': 'Skybags',
#   'Mfg_date': '29/8/2020'},
#  '10002': {'prod_name': 'Track Bag',
#   'price': 500,
#   'quantity': 60,
#   'Brand': 'Puma',
#   'Mfg_date': '9/5/2021'},
#  '10003': {'prod_name': 'Gym Bag',
#   'price': 300,
#   'quantity': 40,
#   'Brand': 'American Tourist',
#   'Mfg_date': '2/2/2021'},
#  '10004': {'prod_name': 'Travel Bag',
#   'price': 900,
#   'quantity': 100,
#   'Brand': 'Adidas',
#   'Mfg_date': '19/4/2020'},
#  '10005': {'prod_name': 'Hand Bag',
#   'price': 400,
#   'quantity': 200,
#   'Brand': 'Adidas',
#   'Mfg_date': '1/7/2020'},
#  '10006': {'prod_name': 'Laptop Bag',
#   'price': 800,
#   'quantity': 100,
#   'Brand': 'Apple',
#   'Mfg_date': '20/3/2020'},
#  '10007': {'prod_name': 'Sports Bag',
#   'price': 200,
#   'quantity': 250,
#   'Brand': 'Puma',
#   'Mfg_date': '19/7/2021'},
#  '10008': {'prod_name': ' Ball pen',
#   'price': 50,
#   'quantity': 200,
# ...

# %% [markdown]
# ## Add new item in inventory

# %%
prod_id = str(input("Enter product id:"))
prod_name = str(input("Enter name of the product:"))
price = int(input("Enter price:"))
quantity = int(input("Enter quantity:"))
Brand = str(input("Enter the brand name :"))
Mfg_date = str(input("Enter the manufacturing date :"))


record[prod_id] = {'prod_name': prod_name, 'price': price, 'quantity': quantity, 'Brand' : Brand, 'Mfg_date': Mfg_date}

js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product id:10031
# Enter name of the product:Whitener
# Enter price:40
# Enter quantity:30
# Enter the brand name :Camlin
# Enter the manufacturing date :15/7/2021

# %%
record
# Out:
# {'10001': {'prod_name': 'School Bag',
#   'price': 2000,
#   'quantity': 50,
#   'Brand': 'Skybags',
#   'Mfg_date': '29/8/2020'},
#  '10002': {'prod_name': 'Track Bag',
#   'price': 500,
#   'quantity': 60,
#   'Brand': 'Puma',
#   'Mfg_date': '9/5/2021'},
#  '10003': {'prod_name': 'Gym Bag',
#   'price': 300,
#   'quantity': 40,
#   'Brand': 'American Tourist',
#   'Mfg_date': '2/2/2021'},
#  '10004': {'prod_name': 'Travel Bag',
#   'price': 900,
#   'quantity': 100,
#   'Brand': 'Adidas',
#   'Mfg_date': '19/4/2020'},
#  '10005': {'prod_name': 'Hand Bag',
#   'price': 400,
#   'quantity': 200,
#   'Brand': 'Adidas',
#   'Mfg_date': '1/7/2020'},
#  '10006': {'prod_name': 'Laptop Bag',
#   'price': 800,
#   'quantity': 100,
#   'Brand': 'Apple',
#   'Mfg_date': '20/3/2020'},
#  '10007': {'prod_name': 'Sports Bag',
#   'price': 200,
#   'quantity': 250,
#   'Brand': 'Puma',
#   'Mfg_date': '19/7/2021'},
#  '10008': {'prod_name': ' Ball pen',
#   'price': 50,
#   'quantity': 200,
# ...
